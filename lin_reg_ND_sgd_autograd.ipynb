# %%
#
# Project:
#      PyTorch Dojo (https://github.com/wo3kie/ml-dojo)
#
# Author:
#      Lukasz Czerwinski (https://www.lukaszczerwinski.pl/)
#

# %% [markdown]
# $$ \text{s - Samples} $$
# $$ \text{f - Features} $$
# $$
# \begin{pmatrix}
# y_0 \\
# y_1 \\
# \vdots \\
# y_S \\
# \end{pmatrix} =
#
# \begin{pmatrix}
# x_{00} & x_{01} & \cdots & x_{0F} \\
# x_{10} & x_{11} & \cdots & x_{1F} \\
# \vdots & \vdots & \ddots & \vdots \\
# x_{S0} & x_{S1} & \cdots & x_{SF} \\
# \end{pmatrix}
# \cdot
# \begin{pmatrix}
# w_0 \\
# w_1 \\
# \vdots \\
# w_F \\
# \end{pmatrix}
# +
# \begin{pmatrix}
# b \\
# b \\
# \vdots \\
# b \\
# \end{pmatrix}
# $$

# %%
from torch import manual_seed, no_grad, randn, Size, Tensor
from torch.nn import Linear, MSELoss
from torch.nn.functional import mse_loss
from torch.optim import SGD

import import_ipynb
from common import assert_eq, T # type: ignore


def linear_regression_nd_sgd_autograd(X: Tensor, Y: Tensor, epochs=1000, lr=0.1) -> tuple[Tensor, Tensor, Tensor]:
    """
    Performs linear regression using Stochastic Gradient Descent (SGD) with autograd.

    Args:
        X: Input features of shape (s, f)
        Y: Target values of shape (s, 1)
        epochs: Number of training epochs
        lr: Learning rate

    Returns:
        tuple: (loss, weights, bias)
    """

    (s, f) = X.shape

    assert_eq(X.shape, (s, f))
    assert_eq(Y.shape, (s, 1))

    model = Linear(in_features=f, out_features=1, bias=True)
    W = weights = model.weight
    b = bias = model.bias

    assert_eq(W.shape, (1, f))
    assert_eq(b.shape, (1,))

    optimizer = SGD(model.parameters(), lr=lr)

    for _ in range(epochs):
        optimizer.zero_grad()
        
        Z = logits = model(X)
        L = loss = mse_loss(Z, Y)

        L.backward()
        optimizer.step()

    return (loss, model)


def _test_linear_regression_nd_sgd_autograd(s: int, W: Tensor, b: Tensor, epochs=1000, lr=0.1, atol=0.01) -> None:
    """
    Tests the linear regression using Stochastic Gradient Descent (SGD) with autograd, 
    by generating synthetic data with known weights, and verifies that the computed weights and bias are correct.

    Args:
        s: Number of samples
        W: Model's weight(s)
        b: Model's bias
    """

    (s, f) = (s, W.shape[0])
    
    X = randn(s, f)
    assert_eq(X.shape, (s, f))

    Y = X @ W + b
    assert_eq(Y.shape, (s, 1))

    (loss, model) = linear_regression_nd_sgd_autograd(X, Y, epochs, lr)
    assert_eq(loss, 0.0, atol)
    assert_eq(X @ W + b, model(X), atol)


def test_linear_regression_nd_sgd_autograd() -> None:
    _test_linear_regression_nd_sgd_autograd(10, W=T([[0.1]]), b=0.2)
    _test_linear_regression_nd_sgd_autograd(10, W=T([[0.3], [0.4]]), b=0.5)
    _test_linear_regression_nd_sgd_autograd(200, W=T([[0.6], [0.7], [0.8]]), b=0.9)


if __name__ == "__main__":
    test_linear_regression_nd_sgd_autograd()
